# %% [markdown]
# # Visualizing data
# `matplotlib` is able to produce meaningful data plots right in a notebook with little effort using Pandas DataFrames. This notebook covers a few of those capabilities.

# %%
# Load your dataframe
import pandas as pd
csv_url = "https://raw.githubusercontent.com/paiml/wine-ratings/main/wine-ratings.csv"
df = pd.read_csv(csv_url, index_col=0)
df.drop('grape', axis=1, inplace=True)
df = df.dropna()
df.head()
# Out:
#                                                 name                   region  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    Mendocino, California
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...               California
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...               California
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013  North Coast, California
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014               California
#
#     variety  rating                                              notes
# 0  Red Wine    91.0  This is a very special, limited release of 100...
# 1  Red Wine    89.0  The California Gold Rush was a period of coura...
# 2  Red Wine    90.0  The California Gold Rush was a period of coura...
# 3  Red Wine    91.0  The wine has a deep, rich purple color. An int...
# 4  Red Wine    90.0  Batch #004 is the first release of the 2014 vi...

# %% [markdown]
# Import `matplotlib` and set the `inline` magic line

# %%
# !pip install matplotlib

# %matplotlib inline
# Out:
# Requirement already satisfied: matplotlib in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: six>=1.5 in /home/ibad/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
df['rating'] = df['rating'].apply(lambda x: int(x))

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['rating'].plot()
# Out:
# <Axes: >

# %%
df["variety"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df["variety"].plot()
#
# File ~/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:446, in MPLPlot.generate(self)
#     444 def generate(self) -> None:
#     445     self._args_adjust()
# --> 446     self._compute_plot_data()
#     447     self._setup_subplots()
#     448     self._make_plot()
#
# File ~/Desktop/MLOps_Duke_Coursera/venv/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:632, in MPLPlot._compute_plot_data(self)
#     630 # no non-numeric frames or series allowed
#     631 if is_empty:
# --> 632     raise TypeError("no numeric data to plot")
#     634 self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
df.plot.scatter(x="rating", y="variety", alpha=0.5)
# Out:
# <Axes: xlabel='rating', ylabel='variety'>
